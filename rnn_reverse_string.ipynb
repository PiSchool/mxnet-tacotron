# %%
# %matplotlib inline
import mxnet as mx
ctx=mx.cpu(0)
import logging
logging.getLogger().setLevel(logging.DEBUG)
from char_utils import *

# %%
num_hidden=64
embed_size=64
batch_size=100
dataset_size=10000

# %%
train_set, inverse_train_set, eval_set, inverse_eval_set = generate_chars_train_eval_sets(dataset_size=dataset_size)

train_iter = generate_chars_iterators(train_set=train_set, label_set=inverse_train_set, batch_size=batch_size)
eval_iter = generate_chars_iterators(train_set=eval_set, label_set=inverse_eval_set, batch_size=batch_size)

# %%
data = mx.sym.Variable('data')
label = mx.sym.Variable('softmax_label')

embed = mx.sym.Embedding(
    data=data,
    input_dim=vocab_size,
    output_dim=embed_size
)

bi_cell = mx.rnn.BidirectionalCell(
    mx.rnn.GRUCell(num_hidden=num_hidden, prefix="gru1_"),
    mx.rnn.GRUCell(num_hidden=num_hidden, prefix="gru2_"),
    output_prefix="bi_"
)

encoder = mx.rnn.ResidualCell(bi_cell)
        
_, encoder_state = encoder.unroll(
    length=max_string_len,
    inputs=embed,
    merge_outputs=False
)

encoder_state = mx.sym.concat(encoder_state[0][0],encoder_state[1][0])

decoder = mx.rnn.GRUCell(num_hidden=num_hidden*2)

rnn_output, decoder_state = decoder.unroll(
    length=num_hidden*2,
    inputs=encoder_state,
    merge_outputs=True
)

flat=mx.sym.Flatten(data=rnn_output)

fc=mx.sym.FullyConnected(
    data=flat,
    num_hidden=max_string_len*vocab_size
)
#drop=mx.sym.Dropout(data=fc, p=0.5)
act=mx.sym.Activation(data=fc, act_type='relu')


out = mx.sym.Reshape(data=act, shape=((0,max_string_len,vocab_size)))

#out=mx.sym.round(out)

net = mx.sym.LinearRegressionOutput(data=out, label=label)

# %%
model = mx.module.Module(net)
model.fit(
    train_data=train_iter,
    eval_data=eval_iter,
    eval_metric = 'acc',
    optimizer=mx.optimizer.Adam(rescale_grad=1/batch_size),
    #optimizer_params={'learning_rate':0.001, 'momentum':0.9},
    initializer=mx.initializer.Xavier(),
    batch_end_callback=mx.callback.Speedometer(batch_size, 10),
    num_epoch=8
)
# Out:
# INFO:root:Epoch[0] Batch [10]	Speed: 144.64 samples/sec	accuracy=0.880303
# INFO:root:Epoch[0] Batch [20]	Speed: 153.50 samples/sec	accuracy=0.882650
# INFO:root:Epoch[0] Batch [30]	Speed: 153.83 samples/sec	accuracy=0.881433
# INFO:root:Epoch[0] Batch [40]	Speed: 144.31 samples/sec	accuracy=0.881317
# INFO:root:Epoch[0] Batch [50]	Speed: 146.15 samples/sec	accuracy=0.882742
# INFO:root:Epoch[0] Batch [60]	Speed: 141.91 samples/sec	accuracy=0.883058
# INFO:root:Epoch[0] Batch [70]	Speed: 144.96 samples/sec	accuracy=0.884042
# INFO:root:Epoch[0] Batch [80]	Speed: 158.92 samples/sec	accuracy=0.884625
# INFO:root:Epoch[0] Batch [90]	Speed: 159.08 samples/sec	accuracy=0.886483
# INFO:root:Epoch[0] Train-accuracy=0.885815
# INFO:root:Epoch[0] Time cost=66.623
# INFO:root:Epoch[0] Validation-accuracy=0.886467
# INFO:root:Epoch[1] Batch [10]	Speed: 160.80 samples/sec	accuracy=0.887818
# INFO:root:Epoch[1] Batch [20]	Speed: 163.24 samples/sec	accuracy=0.889400
# INFO:root:Epoch[1] Batch [30]	Speed: 162.34 samples/sec	accuracy=0.890633
# INFO:root:Epoch[1] Batch [40]	Speed: 155.78 samples/sec	accuracy=0.891367
# INFO:root:Epoch[1] Batch [50]	Speed: 149.04 samples/sec	accuracy=0.895300
# INFO:root:Epoch[1] Batch [60]	Speed: 115.08 samples/sec	accuracy=0.893708
# INFO:root:Epoch[1] Batch [70]	Speed: 108.31 samples/sec	accuracy=0.899108
# INFO:root:Epoch[1] Batch [80]	Speed: 143.75 samples/sec	accuracy=0.899550
# INFO:root:Epoch[1] Batch [90]	Speed: 144.18 samples/sec	accuracy=0.902783
# INFO:root:Epoch[1] Train-accuracy=0.906213
# INFO:root:Epoch[1] Time cost=69.940
# INFO:root:Epoch[1] Validation-accuracy=0.905792
# INFO:root:Epoch[2] Batch [10]	Speed: 147.93 samples/sec	accuracy=0.908598
# INFO:root:Epoch[2] Batch [20]	Speed: 118.65 samples/sec	accuracy=0.911325
# INFO:root:Epoch[2] Batch [30]	Speed: 131.05 samples/sec	accuracy=0.914850
# INFO:root:Epoch[2] Batch [40]	Speed: 149.79 samples/sec	accuracy=0.915558
# INFO:root:Epoch[2] Batch [50]	Speed: 158.89 samples/sec	accuracy=0.918458
# INFO:root:Epoch[2] Batch [60]	Speed: 159.55 samples/sec	accuracy=0.920667
# INFO:root:Epoch[2] Batch [70]	Speed: 140.15 samples/sec	accuracy=0.922983
# INFO:root:Epoch[2] Batch [80]	Speed: 147.52 samples/sec	accuracy=0.924008
# INFO:root:Epoch[2] Batch [90]	Speed: 154.77 samples/sec	accuracy=0.924392
# INFO:root:Epoch[2] Train-accuracy=0.926574
# INFO:root:Epoch[2] Time cost=69.277
# INFO:root:Epoch[2] Validation-accuracy=0.922958
# INFO:root:Epoch[3] Batch [10]	Speed: 148.94 samples/sec	accuracy=0.928288
# INFO:root:Epoch[3] Batch [20]	Speed: 137.09 samples/sec	accuracy=0.928500
# INFO:root:Epoch[3] Batch [30]	Speed: 150.97 samples/sec	accuracy=0.930025
# INFO:root:Epoch[3] Batch [40]	Speed: 159.50 samples/sec	accuracy=0.929842
# INFO:root:Epoch[3] Batch [50]	Speed: 160.84 samples/sec	accuracy=0.931525
# INFO:root:Epoch[3] Batch [60]	Speed: 149.94 samples/sec	accuracy=0.932400
# INFO:root:Epoch[3] Batch [70]	Speed: 157.33 samples/sec	accuracy=0.932375
# INFO:root:Epoch[3] Batch [80]	Speed: 159.53 samples/sec	accuracy=0.932500
# INFO:root:Epoch[3] Batch [90]	Speed: 145.78 samples/sec	accuracy=0.933408
# INFO:root:Epoch[3] Train-accuracy=0.930713
# INFO:root:Epoch[3] Time cost=65.703
# INFO:root:Epoch[3] Validation-accuracy=0.925942
# INFO:root:Epoch[4] Batch [10]	Speed: 158.96 samples/sec	accuracy=0.932886
# INFO:root:Epoch[4] Batch [20]	Speed: 157.55 samples/sec	accuracy=0.933225
# INFO:root:Epoch[4] Batch [30]	Speed: 155.99 samples/sec	accuracy=0.933583
# INFO:root:Epoch[4] Batch [40]	Speed: 156.02 samples/sec	accuracy=0.932892
# INFO:root:Epoch[4] Batch [50]	Speed: 152.79 samples/sec	accuracy=0.933825
# INFO:root:Epoch[4] Batch [60]	Speed: 141.06 samples/sec	accuracy=0.934067
# INFO:root:Epoch[4] Batch [70]	Speed: 153.14 samples/sec	accuracy=0.933808
# INFO:root:Epoch[4] Batch [80]	Speed: 151.19 samples/sec	accuracy=0.934925
# INFO:root:Epoch[4] Batch [90]	Speed: 151.70 samples/sec	accuracy=0.933542
# INFO:root:Epoch[4] Train-accuracy=0.932843
# INFO:root:Epoch[4] Time cost=65.786
# INFO:root:Epoch[4] Validation-accuracy=0.933050
# INFO:root:Epoch[5] Batch [10]	Speed: 148.08 samples/sec	accuracy=0.934826
# INFO:root:Epoch[5] Batch [20]	Speed: 47.20 samples/sec	accuracy=0.933125
# INFO:root:Epoch[5] Batch [30]	Speed: 106.47 samples/sec	accuracy=0.935608
# INFO:root:Epoch[5] Batch [40]	Speed: 87.42 samples/sec	accuracy=0.933450
# INFO:root:Epoch[5] Batch [50]	Speed: 137.41 samples/sec	accuracy=0.935233
# INFO:root:Epoch[5] Batch [60]	Speed: 158.70 samples/sec	accuracy=0.934992
# INFO:root:Epoch[5] Batch [70]	Speed: 95.88 samples/sec	accuracy=0.935508
# INFO:root:Epoch[5] Batch [80]	Speed: 70.81 samples/sec	accuracy=0.934208
# INFO:root:Epoch[5] Batch [90]	Speed: 115.08 samples/sec	accuracy=0.935167
# INFO:root:Epoch[5] Train-accuracy=0.932861
# INFO:root:Epoch[5] Time cost=104.426
# INFO:root:Epoch[5] Validation-accuracy=0.936642
# INFO:root:Epoch[6] Batch [10]	Speed: 133.45 samples/sec	accuracy=0.935242
# INFO:root:Epoch[6] Batch [20]	Speed: 122.21 samples/sec	accuracy=0.934908
# INFO:root:Epoch[6] Batch [30]	Speed: 148.74 samples/sec	accuracy=0.934858
# INFO:root:Epoch[6] Batch [40]	Speed: 113.06 samples/sec	accuracy=0.934825
# INFO:root:Epoch[6] Batch [50]	Speed: 119.69 samples/sec	accuracy=0.935358
# INFO:root:Epoch[6] Batch [60]	Speed: 105.83 samples/sec	accuracy=0.935892
# INFO:root:Epoch[6] Batch [70]	Speed: 117.06 samples/sec	accuracy=0.935750
# INFO:root:Epoch[6] Batch [80]	Speed: 128.51 samples/sec	accuracy=0.934942
# INFO:root:Epoch[6] Batch [90]	Speed: 156.11 samples/sec	accuracy=0.935833
# INFO:root:Epoch[6] Train-accuracy=0.935120
# INFO:root:Epoch[6] Time cost=78.528
# INFO:root:Epoch[6] Validation-accuracy=0.930917
# INFO:root:Epoch[7] Batch [10]	Speed: 155.08 samples/sec	accuracy=0.934538
# INFO:root:Epoch[7] Batch [20]	Speed: 109.07 samples/sec	accuracy=0.935392
# INFO:root:Epoch[7] Batch [30]	Speed: 121.66 samples/sec	accuracy=0.935258
# INFO:root:Epoch[7] Batch [40]	Speed: 148.78 samples/sec	accuracy=0.934917
# INFO:root:Epoch[7] Batch [50]	Speed: 114.45 samples/sec	accuracy=0.936033
# INFO:root:Epoch[7] Batch [60]	Speed: 120.31 samples/sec	accuracy=0.935900
# INFO:root:Epoch[7] Batch [70]	Speed: 142.86 samples/sec	accuracy=0.934717
# INFO:root:Epoch[7] Batch [80]	Speed: 133.25 samples/sec	accuracy=0.934517
# INFO:root:Epoch[7] Batch [90]	Speed: 146.20 samples/sec	accuracy=0.935358
# INFO:root:Epoch[7] Train-accuracy=0.936046
# INFO:root:Epoch[7] Time cost=77.271
# INFO:root:Epoch[7] Validation-accuracy=0.925800

# %%
import difflib

testset_size=100

test_set, inverse_test_set, _, _ = generate_chars_train_eval_sets(dataset_size=testset_size)

test_iter = generate_chars_iterators(train_set=test_set, label_set=inverse_test_set, batch_size=1)

predictions=model.predict(test_iter)

match_count=0
for i,pred in enumerate(predictions):
    matched = ints2text(onehot2int(mx.ndarray.round(predictions[i]))) == ints2text(inverse_test_set[i])
    if matched:
        match_count+=1
    else:       
        print(i)
        inverse=ints2text(inverse_test_set[i])
        print(inverse)
        inverse_pred=ints2text(onehot2int(mx.ndarray.round(predictions[i])))
        print(inverse_pred)
        print(matched)
        for i,s in enumerate(difflib.ndiff(inverse, inverse_pred)):
            if s[0]==' ': continue
            elif s[0]=='-':
                print(u'Delete "{}" from position {}'.format(s[-1],i))
            elif s[0]=='+':
                print(u'Add "{}" to position {}'.format(s[-1],i))    
        print("--------------------")

print("Matched %d/%d times" % (match_count,testset_size))
# Out:
# 4
# #edfbbabdebdcd§
# #edfbbabdebdad§
# False
# Delete "c" from position 12
# Add "a" to position 13
# --------------------
# 5
# #dedcdcfcacecc§
# #dedcdcfcaceac§
# False
# Delete "c" from position 12
# Add "a" to position 13
# --------------------
# 13
# #fbbcbeedbeacc§
# #fbbcbeedbeaac§
# False
# Delete "c" from position 12
# Add "a" to position 13
# --------------------
# 26
# #eaacafbfecacc§
# #eaacafbfecaac§
# False
# Delete "c" from position 12
# Add "a" to position 13
# --------------------
# 41
# #afefbabbecdcd§
# #afefbabbecdad§
# False
# Delete "c" from position 12
# Add "a" to position 13
# --------------------
# 55
# #eebadeffabacf§
# #eebadeffabaaf§
# False
# Delete "c" from position 12
# Add "a" to position 13
# --------------------
# 59
# #eaafcabeecaca§
# #eaafcabeecaaa§
# False
# Delete "c" from position 12
# Add "a" to position 13
# --------------------
# 60
# #accaedabdcfcf§
# #accaedabdcfaf§
# False
# Delete "c" from position 12
# Add "a" to position 13
# --------------------
# 62
# #ffceffdebdeca§
# #ffceffdebdeaa§
# False
# Delete "c" from position 12
# Add "a" to position 13
# --------------------
# 74
# #afeaadcddeece§
# #afeaadcddeeae§
# False
# Delete "c" from position 12
# Add "a" to position 13
# --------------------
# 89
# #cbdbcdbdacbcc§
# #cbdbcdbdacbac§
# False
# Delete "c" from position 12
# Add "a" to position 13
# --------------------
# 95
# #eadfeeffebbcf§
# #eadfeeffebbaf§
# False
# Delete "c" from position 12
# Add "a" to position 13
# --------------------
# 97
# #daadafbeacacc§
# #daadafbeacaac§
# False
# Delete "c" from position 12
# Add "a" to position 13
# --------------------
# Matched 87/100 times
